# %% [markdown]
# # __Distance qualitative analysis__

# %% [markdown]
# ## __Model definitions__

# %%
# ANI


# import the calculators
from torch import device
from torchani.models import ANI1x, ANI2x, ANI1ccx

ani1x_calc = ANI1x().ase()
ani1ccx_calc = ANI1ccx().ase()
ani2x_calc = ANI2x().ase()

# device type can defined via torch and parsed to the model via .to() method
#device_ = device('cpu')
#model_ = ANI1x(periodic_table_index=True).to(device_).double().ase()


# MACE
from mace.calculators import mace_mp, mace_off

macemp = mace_mp(
    model="medium", 
    dispersion=False, 
    default_dtype="float32", 
    device='cpu',
    )

maceoff = mace_off(
    model="medium", 
    device='cpu',
    default_dtype='float32'
    )

# ORB

from orb_models.forcefield.pretrained import orb_v2, orb_d3_v2
from orb_models.forcefield.calculator import ORBCalculator

orbff_v2 = orb_v2(device='cpu')
orb_calc_v2 = ORBCalculator(orbff_v2, device='cpu')

orbff_d3_v2 = orb_d3_v2(device='cpu')
orb_calc_d3_v2 = ORBCalculator(orbff_d3_v2, device='cpu')


CALC_NAME = 'ALL'
# Out:
# /Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torchani/aev.py:16: UserWarning: cuaev not installed
#   warnings.warn("cuaev not installed")
# /Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torchani/resources/
# /Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torchani/resources/
# /Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torchani/resources/
# /Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# Using Materials Project MACE for MACECalculator with /Users/sergiortizropero/.cache/mace/20231203mace128L1_epoch199model
# Using float32 for MACECalculator, which is faster but less accurate. Recommended for MD. Use float64 for geometry optimization.
# Default dtype float32 does not match model dtype float64, converting models to float32.
# Using MACE-OFF23 MODEL for MACECalculator with /Users/sergiortizropero/.cache/mace/MACE-OFF23_medium.model
# Using float32 for MACECalculator, which is faster but less accurate. Recommended for MD. Use float64 for geometry optimization.
# Default dtype float32 does not match model dtype float64, converting models to float32.
# /Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/mace/calculators/mace.py:135: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(f=model_path, map_location=device)
# /Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/mace/calculators/mace.py:135: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(f=model_path, map_location=device)
# /Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/orb_models/forcefield/pretrained.py:71: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(local_path, map_location="cpu")

# %%
# UMA
from fairchem.core import FAIRChemCalculator
from fairchem.core.units.mlip_unit import load_predict_unit

# define the UMA ASE calculator
uma_predictor = load_predict_unit(
    path='/Users/sergiortizropero/TFG_phys/NNPs_TFG/models/ase_uma/uma-s-1p1.pt', 
    device='cpu',                   
    inference_settings='default',   
)
uma_calc = FAIRChemCalculator(
    uma_predictor,
    task_name='omol',               
)

CALC_NAME = 'UMA'
# Out:
# /Users/sergiortizropero/miniconda3/envs/ASE_UMA_test/lib/python3.12/site-packages/torchtnt/utils/version.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# W0710 22:09:22.793000 32661 site-packages/torch/distributed/elastic/multiprocessing/redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.

# %%
# define the calculators
calculator_list = [ani1x_calc, ani1ccx_calc, ani2x_calc, macemp, maceoff, orb_calc_v2, orb_calc_d3_v2]
calculator_names = ['ANI-1x', 'ANI-1ccx', 'ANI-2x', 'MACE-MP', 'MACE-OFF', 'ORB-V2', 'ORB-D3-V2']
calculator_colors = ['darkviolet', 'crimson', 'deeppink', 'darkgreen', 'mediumseagreen', 'royalblue', 'darkblue']

color_dict = {
    'ANI-1x': 'darkviolet', 
    'ANI-1ccx': 'crimson', 
    'ANI-2x': 'deeppink', 
    'MACE-MP': 'darkgreen', 
    'MACE-OFF':  'mediumseagreen', 
    'ORB-V2': 'royalblue', 
    'ORB-D3-V2': 'darkblue',
    'UMA_small': 'black',
}

# %%
# define the calculators
calculator_list = [uma_calc]
calculator_names = ['UMA_small']
calculator_colors = ['black']

color_dict = {
    'UMA_small': 'black', 
}

# %% [markdown]
# ## __Imports & Functions__

# %%
# general imports
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
#rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)
rc('lines', lw=1, color='b')
rc('legend', loc='best')
plt.rcParams["legend.fancybox"] = False
plt.rcParams["legend.edgecolor"] = 'black'
plt.rcParams['legend.borderpad'] = 0.25
plt.rcParams['legend.fontsize'] = 11
plt.rcParams.update({'pgf.preamble': r'\usepackage{amsmath}'})

from ase import Atoms
from ase.visualize import view
from ase.build import molecule
from ase.io import write, read
from ase.io import Trajectory, trajectory
from ase import build
from ase.data.pubchem import pubchem_atoms_search

# %%
def evaluate_diatomics(atom_str, calculator_list, search_space=None , resolution=None, verbose=True, workdir='./', name='', UMA=False):
    '''
    Definition
    ----------
    Evaluates the PES of simple (homoatomic) diatomic molecules A_2. 

    '''

    # define the resolution and space search
    if resolution is None:
        resolution = 100
    if search_space is None:
        search_space = [0.3, 6.5]
    dist_list = np.linspace(search_space[0], search_space[1], resolution)
    print(f'computing {atom_str}2 PES\tscan range {search_space} Å')

    # save UMA model data in a separate folder to plot all models (dependency issue)
    uma_file_name = os.path.join(workdir, 'PES_diatomics_'+name+'_UMA_small.txt')
    uma_loaded = False
    # IMPORTANT, NAME MUST BE THE ELEMENT OF THE PES!!!

    # evaluate diatomics using each model
    energies = []
    succ_calcs = []

    k = 0
    for calc_ in calculator_list: 
        k += 1

        #try:
        calc_energy_list = []
        
        for d in dist_list:

            # define the configuration
            atoms = Atoms(atom_str + '2', [[0, 0, 0], [0, 0, d]])
            atoms.info = {"charge": 0, "spin": 1} 
            atoms.calc = calc_
            E_pot = atoms.get_potential_energy()
            calc_energy_list.append(E_pot)
        
        if not UMA:
            atom = Atoms(atom_str)
            atom.calc = calc_
            atom_dissociated = 2 * atom.get_potential_energy()
            print(f'ATOM SYSTEM {atom_str}, energy {atom_dissociated * 0.5}')
            corrected_energies = np.array(calc_energy_list) - atom_dissociated
        else:
            # precomputed monoatomic energies (FROM MACE)
            # TODO correct the zero for UMA a partir de CCSD(T) AIXÒ HO HE DE FER JO PELS SISTEMES 
            precomputed_DFT = {
                'H' : -13.571965217590332,
                'N' : -1488.8184525763209
            }
            
            print('UMA MODEL, SETTING 0.0 FOR INFINITE DISTANCE (ARBITRARY)')
            corrected_energies = np.array(calc_energy_list) - 2 * precomputed_DFT[atom_str]

        energies.append(corrected_energies)
        succ_calcs.append(calculator_names[k-1])

        # export the data of UMA to a .txt file
        if UMA:
            print('exporting UMA model data')
            if calc_ == uma_calc:
                with open(file=uma_file_name, mode='w') as f:
                    f.write(f'# UMA data for diatomic {name}\n')
                    f.write(f'# DISTANCE\tENERGY\n')
                    for i in range(len(dist_list)):
                        f.write(f'{dist_list[i]}\t{corrected_energies[i]}\n')

        #except: 
            print(f'CALCULATOR {calculator_names[k-1]} FAILED')

    return dist_list, energies, succ_calcs


def plot_diatomics(atom_str_list, calculator_names, color_dict, global_energies, global_distances, workdir='./', ylims=None, name='', switch=False, morse=False, morse_N=False, load_UMA=False):
    '''
    Plot the different PES obtained via `evaluate_diatomics`. 
    Morse: controls wether to plot the morse potential (only for H and N)
    '''
    def morse_funct(x):
        return 4.7446 * (1 - np.exp(- 1.9426 * (x - 0.7416)))**2

    def morse_funct_N(x):
        return 9.904 * (1 - np.exp(- 2.85 * (x - 1.080)))**2

    nrows = int(len(atom_str_list)/2)
    ncols = 2
    fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(int(4*ncols), int(4*nrows)))
    
    if nrows == 1:
        ax_list = [ax for ax in axes]

    elif nrows == 2:
        ax_list = [axes[0, 0], axes[0, 1], axes[1, 0], axes[1, 1]]

    elif nrows == 3:
        ax_list = [axes[0, 0], axes[0, 1], axes[1, 0], axes[1, 1], axes[2, 0], axes[2, 1]]

    else: 
        raise ValueError('num of rows exploded')

    for i in range(len(atom_str_list)):
        ax_list[i].tick_params(bottom=True, top=True, left=True, right=False, direction="in")
        ax_list[i].tick_params(labelbottom=True, labeltop=False, labelleft=True, labelright=False, direction="in")

        if morse_N:
            x_array = np.array(global_distances[0])
            y_morse = morse_funct_N(x_array)
            y_new = y_morse - y_morse[-1]
            ax_list[i].plot(global_distances[0], y_new, label=r'$\textnormal{' + r'Morse N$_2$' + r'}$', color='black', lw=1.5, alpha=0.8)

        if morse:
            x_array = np.array(global_distances[0])
            y_morse = morse_funct(x_array)
            y_new = y_morse - y_morse[-1]
            ax_list[i].plot(global_distances[0], y_new, label=r'$\textnormal{' + r'Morse H$_2$' + r'}$', color='black', lw=1.5, alpha=0.8)

        # retrieve UMA data
        # IMPORTANT: name variable must be the same as in compute_diatomics
        if load_UMA:
            uma_file_path = os.path.join(workdir, 'PES_diatomics_'+atom_str_list[i]+'_UMA_small.txt')
            
            if os.path.exists(uma_file_path):
                print(f'loading UMA file {uma_file_path}')
                uma_data = np.loadtxt(delimiter='\t', dtype='float', fname=uma_file_path)
                global_distances.append(uma_data[:,0])
                global_energies.append(uma_data[:,1])
                uma_loaded = True
                #calculator_names.append('UMA_small')
            else:
                print('UMA LOAD FAILED')

            print(global_distances)

        for k in range(len(calculator_names[i])):
            #print(calculator_names)
            #print(global_distances[i])
            #print(global_energies[i])
            ax_list[i].plot(global_distances[i], global_energies[i][k][:], label=r'$\textnormal{' + calculator_names[i][k] + r'}$', color=color_dict[calculator_names[i][k]], alpha=0.9)

            if ylims is not None:
                ax_list[i].set_ylim(ylims[i][0], ylims[i][1])

        ax_list[i].set(xlabel=r'$\textnormal{' + f'{atom_str_list[i]}--{atom_str_list[i]}' + r' bond distance}\;\textnormal{(Å)}$')
        
        if switch:
            if i == len(atom_str_list)-1:
                ax_list[i].legend(loc='center right', bbox_to_anchor=(1.45, 0.5), prop={'size': 9})

            if i%ncols == 0:
                ax_list[i].set(ylabel=r'$\textnormal{potential energy}\;\textnormal{(eV)}$')

        else: 
            ax_list[i].legend(loc='best', prop={'size': 9})
            ax_list[i].set(ylabel=r'$\textnormal{potential energy}\;\textnormal{(eV)}$')

    plt.tight_layout()
    plt.savefig(os.path.join(workdir, f'PES_diatomics_{name}.pdf'))
    plt.show(fig)

# %% [markdown]
# ### __Diatomic Potentials__

# %%
# define the diatomics and the PES scan range
atom_str_list = ['H', 'N', 'C', 'O', 'Si', 'Cl']
upper_lim = 6.0
search_list = [[0.3, upper_lim], [0.9, upper_lim], [0.8, upper_lim], [0.9, upper_lim], [1.5, upper_lim], [1.5, upper_lim]]

# create path to store results
workdir = 'PES_distances'
if not os.path.isdir(workdir):
    os.makedirs(workdir)

# dimension: [atom_len, calc_len, resolution]
global_energies = []

# dimension: [atom_len, resolution]
global_distances = []

global_succ_calcs = []

# compute all the PES
for i in range(len(atom_str_list)):
    dist_list, energies, succ_calcs = evaluate_diatomics(atom_str_list[i], calculator_list, search_space=search_list[i], resolution=100)
    global_energies.append(energies)
    global_distances.append(dist_list)
    global_succ_calcs.append(succ_calcs)

plot_diatomics(atom_str_list, global_succ_calcs, color_dict=color_dict, global_energies=global_energies, global_distances=global_distances, workdir=workdir, switch=False, name='COSiCl')
# Out:
# computing H2 PES	scan range [0.3, 6.0] Å
# ATOM SYSTEM H, energy -16.470407975640555
# ATOM SYSTEM H, energy -16.436944462885357
# ATOM SYSTEM H, energy -13.928987137388805
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 21
#      19 # compute all the PES
#      20 for i in range(len(atom_str_list)):
# ---> 21     dist_list, energies, succ_calcs = evaluate_diatomics(atom_str_list[i], calculator_list, search_space=search_list[i], resolution=100)
#      22     global_energies.append(energies)
#      23     global_distances.append(dist_list)
#
# Cell In[10], line 39, in evaluate_diatomics(atom_str, calculator_list, search_space, resolution, verbose, workdir, name, UMA)
#      37     atoms.info = {"charge": 0, "spin": 1}
#      38     atoms.calc = calc_
# ---> 39     E_pot = atoms.get_potential_energy()
#      40     calc_energy_list.append(E_pot)
#      42 if not UMA:
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/atoms.py:770, in Atoms.get_potential_energy(self, force_consistent, apply_constraint)
#     767     energy = self._calc.get_potential_energy(
#     768         self, force_consistent=force_consistent)
#     769 else:
# --> 770     energy = self._calc.get_potential_energy(self)
#     771 if apply_constraint:
#     772     for constraint in self.constraints:
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/calculators/abc.py:24, in GetPropertiesMixin.get_potential_energy(self, atoms, force_consistent)
#      22 else:
#      23     name = 'energy'
# ---> 24 return self.get_property(name, atoms)
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/calculators/calculator.py:538, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     535     if self.use_cache:
#     536         self.atoms = atoms.copy()
# --> 538     self.calculate(atoms, [name], system_changes)
#     540 if name not in self.results:
#     541     # For some reason the calculator was not able to do what we want,
#     542     # and that is OK.
#     543     raise PropertyNotImplementedError(
#     544         '{} not present in this ' 'calculation'.format(name)
#     545     )
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/mace/calculators/mace.py:300, in MACECalculator.calculate(self, atoms, properties, system_changes)
#     298 for i, model in enumerate(self.models):
#     299     batch = self._clone_batch(batch_base)
# --> 300     out = model(
#     301         batch.to_dict(),
#     302         compute_stress=compute_stress,
#     303         training=self.use_compile,
#     304     )
#     305     if self.model_type in ["MACE", "EnergyDipoleMACE"]:
#     306         ret_tensors["energies"][i] = out["energy"].detach()
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/mace/modules/models.py:419, in ScaleShiftMACE.forward(self, data, training, compute_force, compute_virials, compute_stress, compute_displacement, compute_hessian)
#     409 for interaction, product, readout in zip(
#     410     self.interactions, self.products, self.readouts
#     411 ):
#     412     node_feats, sc = interaction(
#     413         node_attrs=data["node_attrs"],
#     414         node_feats=node_feats,
#    (...)
#     417         edge_index=data["edge_index"],
#     418     )
# --> 419     node_feats = product(
#     420         node_feats=node_feats, sc=sc, node_attrs=data["node_attrs"]
#     421     )
#     422     node_feats_list.append(node_feats)
#     423     node_es_list.append(
#     424         readout(node_feats, node_heads)[num_atoms_arange, node_heads]
#     425     )  # {[n_nodes, ], }
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/mace/modules/blocks.py:291, in EquivariantProductBasisBlock.forward(self, node_feats, sc, node_attrs)
#     285 def forward(
#     286     self,
#     287     node_feats: torch.Tensor,
#     288     sc: Optional[torch.Tensor],
#     289     node_attrs: torch.Tensor,
#     290 ) -> torch.Tensor:
# --> 291     node_feats = self.symmetric_contractions(node_feats, node_attrs)
#     292     if self.use_sc and sc is not None:
#     293         return self.linear(node_feats) + sc
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/mace/modules/symmetric_contraction.py:82, in SymmetricContraction.forward(self, x, y)
#      81 def forward(self, x: torch.Tensor, y: torch.Tensor):
# ---> 82     outs = [contraction(x, y) for contraction in self.contractions]
#      83     return torch.cat(outs, dim=-1)
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/mace/modules/symmetric_contraction.py:82, in <listcomp>(.0)
#      81 def forward(self, x: torch.Tensor, y: torch.Tensor):
# ---> 82     outs = [contraction(x, y) for contraction in self.contractions]
#      83     return torch.cat(outs, dim=-1)
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/mace/modules/symmetric_contraction.py:213, in Contraction.forward(self, x, y)
#     212 def forward(self, x: torch.Tensor, y: torch.Tensor):
# --> 213     out = self.graph_opt_main(
#     214         self.U_tensors(self.correlation),
#     215         self.weights_max,
#     216         x,
#     217         y,
#     218     )
#     219     for i, (weight, contract_weights, contract_features) in enumerate(
#     220         zip(self.weights, self.contractions_weighting, self.contractions_features)
#     221     ):
#     222         c_tensor = contract_weights(
#     223             self.U_tensors(self.correlation - i - 1),
#     224             weight,
#     225             y,
#     226         )
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torch/fx/graph_module.py:784, in GraphModule.recompile.<locals>.call_wrapped(self, *args, **kwargs)
#     783 def call_wrapped(self, *args, **kwargs):
# --> 784     return self._wrapped_call(self, *args, **kwargs)
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torch/fx/graph_module.py:348, in _WrappedCall.__call__(self, obj, *args, **kwargs)
#     346         return self.cls_call(obj, *args, **kwargs)
#     347     else:
# --> 348         return super(self.cls, obj).__call__(*args, **kwargs)  # type: ignore[misc]
#     349 except Exception as e:
#     350     assert e.__traceback__
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File <eval_with_key>.9 from <eval_with_key>.8:10 in forward:5, in forward(self, x, y, w, z)
#       4 def forward(self, x, y, w, z):
# ----> 5     tensordot = torch.functional.tensordot(z, y, dims = ((1,), (0,)), out = None);  z = y = None
#       6     einsum = torch.functional.einsum('adb,abc->adbc', tensordot, w);  tensordot = w = None
#       7     tensordot_1 = torch.functional.tensordot(einsum, x, dims = ((1, 3), (3, 2)), out = None);  einsum = x = None
#
# File ~/miniconda3/envs/ASE_all/lib/python3.10/site-packages/torch/functional.py:1355, in tensordot(a, b, dims, out)
#    1352     dims_b = list(range(dims))
#    1354 if out is None:
# -> 1355     return _VF.tensordot(a, b, dims_a, dims_b)  # type: ignore[attr-defined]
#    1356 else:
#    1357     return _VF.tensordot(a, b, dims_a, dims_b, out=out)
#
# KeyboardInterrupt:

# %%
# define the diatomics and the PES scan range
atom_str_list = ['H', 'N']
upper_lim = 6.0
search_list = [[0.3, upper_lim], [0.8, upper_lim]]
#ylims = [[-5.5, 6.5], [-11, 15]]


# create path to store results
workdir = 'PES_distances'
if not os.path.isdir(workdir):
    os.makedirs(workdir)

# dimension: [atom_len, calc_len, resolution]
global_energies = []

# dimension: [atom_len, resolution]
global_distances = []

global_succ_calcs = []

# compute all the PES
for i in range(len(atom_str_list)):
    dist_list, energies, succ_calcs = evaluate_diatomics(
        atom_str_list[i], 
        calculator_list, 
        search_space=search_list[i], 
        resolution=10,
        name=atom_str_list[i],
        workdir=workdir, 
        UMA=False,
        )
    
    global_energies.append(energies)
    global_distances.append(dist_list)
    global_succ_calcs.append(succ_calcs)

plot_diatomics(
    atom_str_list, 
    global_succ_calcs, 
    color_dict=color_dict, 
    global_energies=global_energies, 
    global_distances=global_distances, 
    workdir=workdir, 
    ylims=None, 
    name='HN', 
    switch=True, 
    load_UMA=True
    )
# Out:
# computing H2 PES	scan range [0.3, 6.0] Å
# ATOM SYSTEM H, energy -16.470407975640555
# ATOM SYSTEM H, energy -16.436944462885357
# ATOM SYSTEM H, energy -13.928987137388805
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# ATOM SYSTEM H, energy -1.1589882373809814
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# ATOM SYSTEM H, energy -13.571965217590332
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# ATOM SYSTEM H, energy -0.9333491325378418
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# ATOM SYSTEM H, energy -0.9896421432495117
# computing N2 PES	scan range [0.8, 6.0] Å
# ATOM SYSTEM N, energy -1488.7206522515555
# ATOM SYSTEM N, energy -1487.8121315292547
# ATOM SYSTEM N, energy -1488.8184525763209
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# ATOM SYSTEM N, energy -2.956165313720703
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# <class 'torch.Tensor'>
# torch.float32
# <class 'torch.Tensor'>
# torch.float32
# torch.float64
# ATOM SYSTEM N, energy -1486.375
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# ATOM SYSTEM N, energy -3.093648910522461
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# torch.float32
# torch.float32
# torch.float32
# M torch.float32
# b torch.float32
# mu_batch torch.float32
# ATOM SYSTEM N, energy -3.0446786880493164
# loading UMA file PES_distances/PES_diatomics_H_UMA_small.txt
# [array([0.3       , 0.93333333, 1.56666667, 2.2       , 2.83333333,
#        3.46666667, 4.1       , 4.73333333, 5.36666667, 6.        ]), array([0.8       , 1.37777778, 1.95555556, 2.53333333, 3.11111111,
#        3.68888889, 4.26666667, 4.84444444, 5.42222222, 6.        ]), array([0.3       , 0.93333333, 1.56666667, 2.2       , 2.83333333,
#        3.46666667, 4.1       , 4.73333333, 5.36666667, 6.        ])]
# loading UMA file PES_distances/PES_diatomics_N_UMA_small.txt
# [array([0.3       , 0.93333333, 1.56666667, 2.2       , 2.83333333,
#        3.46666667, 4.1       , 4.73333333, 5.36666667, 6.        ]), array([0.8       , 1.37777778, 1.95555556, 2.53333333, 3.11111111,
#        3.68888889, 4.26666667, 4.84444444, 5.42222222, 6.        ]), array([0.3       , 0.93333333, 1.56666667, 2.2       , 2.83333333,
#        3.46666667, 4.1       , 4.73333333, 5.36666667, 6.        ]), array([0.3       , 0.93333333, 1.56666667, 2.2       , 2.83333333,
#        3.46666667, 4.1       , 4.73333333, 5.36666667, 6.        ])]

# %%
# define the diatomics and the PES scan range
atom_str_list = ['H', 'H']
upper_lim = 6.0
search_list = [[0.3, upper_lim], [0.3, upper_lim]]
ylims = [[-5.5, 6.5], [-5.5, 6.5]]
# create path to store results
workdir = 'PES_distances'
if not os.path.isdir(workdir):
    os.makedirs(workdir)

# dimension: [atom_len, calc_len, resolution]
global_energies = []

# dimension: [atom_len, resolution]
global_distances = []

global_succ_calcs = []

# compute all the PES
for i in range(len(atom_str_list)):
    if i == 0:
        calculator_list = [ani1x_calc, ani1ccx_calc, ani2x_calc]
        calculator_names = ['ANI-1x', 'ANI-1ccx', 'ANI-2x']
    if i == 1:
        calculator_list = [macemp, maceoff, orb_calc_v2, orb_calc_d3_v2]
        calculator_names = ['MACE-MP', 'MACE-OFF', 'ORB-V2', 'ORB-D3-V2']
    dist_list, energies, succ_calcs = evaluate_diatomics(atom_str_list[i], calculator_list, search_space=search_list[i], resolution=100)
    global_energies.append(energies)
    global_distances.append(dist_list)
    global_succ_calcs.append(succ_calcs)

plot_diatomics(atom_str_list, global_succ_calcs, color_dict=color_dict, global_energies=global_energies, global_distances=global_distances, workdir=workdir, ylims=ylims, name='H_morse', switch=False, morse=True)
# Out:
# computing H2 PES	scan range [0.3, 6.5] Å
# computing H2 PES	scan range [0.3, 6.5] Å

# %%
# define the diatomics and the PES scan range
atom_str_list = ['N', 'N']
upper_lim = 6.0
search_list = [[0.8, upper_lim], [0.8, upper_lim]]
ylims = [[-11, 15], [-11, 15]]
# create path to store results
workdir = 'PES_distances'
if not os.path.isdir(workdir):
    os.makedirs(workdir)

# dimension: [atom_len, calc_len, resolution]
global_energies = []

# dimension: [atom_len, resolution]
global_distances = []

global_succ_calcs = []

# compute all the PES
for i in range(len(atom_str_list)):
    if i == 0:
        calculator_list = [ani1x_calc, ani1ccx_calc, ani2x_calc]
        calculator_names = ['ANI-1x', 'ANI-1ccx', 'ANI-2x']
    if i == 1:
        calculator_list = [macemp, maceoff, orb_calc_v2, orb_calc_d3_v2]
        calculator_names = ['MACE-MP', 'MACE-OFF', 'ORB-V2', 'ORB-D3-V2']
    dist_list, energies, succ_calcs = evaluate_diatomics(atom_str_list[i], calculator_list, search_space=search_list[i], resolution=100)
    global_energies.append(energies)
    global_distances.append(dist_list)
    global_succ_calcs.append(succ_calcs)

plot_diatomics(atom_str_list, global_succ_calcs, color_dict=color_dict, global_energies=global_energies, global_distances=global_distances, workdir=workdir, ylims=ylims, name='N_morse', switch=False, morse=False, morse_N=True)
# Out:
# computing N2 PES	scan range [0.8, 6.5] Å
# computing N2 PES	scan range [0.8, 6.5] Å

# %% [markdown]
# ### __UMA potential (standalone)__

# %%
# define the calculators
#calculator_list = [ani1x_calc, ani1ccx_calc, ani2x_calc, macemp, maceoff, orb_calc_v2, orb_calc_d3_v2, uma_calc]
#calculator_names = ['ANI-1x', 'ANI-1ccx', 'ANI-2x', 'MACE-MP', 'MACE-OFF', 'ORB-V2', 'ORB-D3-V2', 'UMA_small']
#calculator_colors = ['darkviolet', 'crimson', 'deeppink', 'darkgreen', 'mediumseagreen', 'royalblue', 'darkblue', 'black']

calculator_list = [uma_calc]
calculator_names = ['UMA_small']
calculator_colors = ['black']

color_dict = {
    'ANI-1x': 'darkviolet', 
    'ANI-1ccx': 'crimson', 
    'ANI-2x': 'deeppink', 
    'MACE-MP': 'darkgreen', 
    'MACE-OFF':  'mediumseagreen', 
    'ORB-V2': 'royalblue', 
    'ORB-D3-V2': 'darkblue',
    'UMA_small': 'black',
}

# %%
# define the diatomics and the PES scan range
atom_str_list = ['H', 'N', 'C', 'O', 'Si', 'Cl']
upper_lim = 6.0
search_list = [[0.3, upper_lim], [0.9, upper_lim], [0.8, upper_lim], [0.9, upper_lim], [1.5, upper_lim], [1.5, upper_lim]]

# create path to store results
workdir = 'PES_distances'
if not os.path.isdir(workdir):
    os.makedirs(workdir)

# dimension: [atom_len, calc_len, resolution]
global_energies = []

# dimension: [atom_len, resolution]
global_distances = []

global_succ_calcs = []

# compute all the PES
for i in range(len(atom_str_list)):
    dist_list, energies, succ_calcs = evaluate_diatomics(atom_str_list[i], calculator_list, search_space=search_list[i], resolution=100)
    global_energies.append(energies)
    global_distances.append(dist_list)
    global_succ_calcs.append(succ_calcs)

plot_diatomics(atom_str_list, global_succ_calcs, color_dict=color_dict, global_energies=global_energies, global_distances=global_distances, workdir=workdir, switch=False, name='COSiCl')
# Out:
# computing H2 PES	scan range [0.3, 6.0] Å
# uma model, setting monoatomic to 0 eV
# computing N2 PES	scan range [0.9, 6.0] Å
# uma model, setting monoatomic to 0 eV
# computing C2 PES	scan range [0.8, 6.0] Å
# uma model, setting monoatomic to 0 eV
# computing O2 PES	scan range [0.9, 6.0] Å
# uma model, setting monoatomic to 0 eV
# computing Si2 PES	scan range [1.5, 6.0] Å
# uma model, setting monoatomic to 0 eV
# computing Cl2 PES	scan range [1.5, 6.0] Å
# uma model, setting monoatomic to 0 eV

# %% [markdown]
# ## __Bond breaking__
# This section aims to explore the same concept as with diatomics, but with general fragments. Given a bond, it is elongated until destruction.
#
#
# Obs. La referència de l'energia, estrictament parlant, hauria de ser l'energia dels fragments. Això no es té en compte. Es pot fixar la referència d'energia en la conformació més estable, igual que en els dihedres o els angles.

# %%
# define the calculators
calculator_list = [ani1x_calc, ani1ccx_calc, ani2x_calc, macemp, maceoff, orb_calc_v2, orb_calc_d3_v2]
calculator_names = ['ANI-1x', 'ANI-1ccx', 'ANI-2x', 'MACE-MP', 'MACE-OFF', 'ORB-V2', 'ORB-D3-V2']
calculator_colors = ['darkviolet', 'crimson', 'deeppink', 'darkgreen', 'mediumseagreen', 'royalblue', 'darkblue']

color_dict = {
    'ANI-1x': 'darkviolet', 
    'ANI-1ccx': 'crimson', 
    'ANI-2x': 'deeppink', 
    'MACE-MP': 'darkgreen', 
    'MACE-OFF':  'mediumseagreen', 
    'ORB-V2': 'royalblue', 
    'ORB-D3-V2': 'darkblue',
}

# %%
def evaluate_bond(molecule, bond_ids, mask,  calculator_list, search_space=None , resolution=None, mol_name='', visualize=True):
    '''
    Definition
    ----------
    Evaluates the PES of the breaking of a bond.
    bond_ids contain the index of the atoms that form the bond. 
    '''


    # create the working directory
    work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
    if not os.path.isdir(work_dir):
        os.makedirs(work_dir)

    # define scan space and resolution
    if resolution is None:
        resolution = 100
    if search_space is None:
        search_space = [1.0, 6.0]
    dist_list = np.linspace(search_space[0], search_space[1], resolution)
    
    # create a trajectory file for the scan (one calculator only)
    if len(calculator_list) == 1:
        traj_path = os.path.join(work_dir, 'bond_scan.traj')
        traj = trajectory.TrajectoryWriter(filename=traj_path, mode='w')


    # compute the distances
    print(f'computing {molecule[bond_ids[0]].symbol}{molecule[bond_ids[0]].index}-{molecule[bond_ids[1]].symbol}{molecule[bond_ids[1]].index} PES\nscan range {search_space} Å')
    print(f'evaluating {len(dist_list)} distances')
    print(f'distances:\n{dist_list}\n')

    # save energies
    energies = []

    # evaluate each calculator
    for calc_ in calculator_list: 

        calc_energy_list = []

        for d in dist_list:

            # define the configuration
            molecule.info = {"charge": 0, "spin": 1}
            molecule.set_distance(bond_ids[0], bond_ids[1], d, mask=mask, fix=0)
            molecule.calc = calc_
            potential_e = molecule.get_potential_energy()
            calc_energy_list.append(potential_e)
        
            if len(calculator_list) == 1:
                traj.write(molecule)

        # compute reference
        # TODO

        energies.append(calc_energy_list)

        if len(calculator_list) == 1:
            traj.close()

    if visualize:
        if len(calculator_list) == 1:
            traj = trajectory.TrajectoryReader(os.path.join('./', mol_name, 'bond_scan.traj'))
            view(traj, viewer='ase')

    return dist_list, energies



def plot_bond(distance_list, energy_list, calculator_names, calculator_colors, mol_name='', calc_name='', bond_name='',plot_markers=False):
    '''
    Plot a bond scan. 
    '''

    work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)

    if plot_markers:
        _color_list = ['black', 'red', 'orange', 'blue']
        _marker_list = ['^', 'd', 'v', 'o']

    fig, axes = plt.subplots(ncols=1, nrows=1, figsize=(6,5)) 
    axes.tick_params(bottom=True, top=True, left=True, right=False, direction="in")
    axes.tick_params(labelbottom=True, labeltop=False, labelleft=True, labelright=False, direction="in")

    for k in range(len(calculator_names)):
        
        # gather the minimum energy structure
        idx = np.argmin(energy_list[k][:])
        min_energy = energy_list[k][idx]
        min_dih = distance_list[idx]

        # TODO convert energy from eV/particle to kcal/mol: 1 eV/molecule = 23.0605 kcal/mol

        axes.plot(distance_list, (np.array(energy_list[k][:])-min_energy), label=r'$\textnormal{' + calculator_names[k] + r'}$', color=calculator_colors[k], alpha=0.9)
        if plot_markers:
            axes.scatter(min_dih, min_energy-min_energy, color=_color_list[k], marker=_marker_list[k], label=r'$\textnormal{energy ref @ ' + f'{min_dih:.3f}' + r' Å}$')

    axes.set(xlabel=r'$\textnormal{' + f'{mol_name} {bond_name}' + r' bond distance}\;\textnormal{(Å)}$', ylabel=r'$\textnormal{potential energy}\;\textnormal{(eV)}$')
    axes.legend(loc='best', title=f'{mol_name}', title_fontsize='large')

    plt.tight_layout()
    plt.savefig(os.path.join(work_dir, f'{mol_name}_{bond_name}_bond_{calc_name}'+'_PES.png'), dpi=300)
    plt.show(fig)

# %% [markdown]
# ### __Examples__

# %%
# define the molecule
mol_name = 'ethane'
molecule = build.molecule('C2H6')

# parameters

bond_name = 'C-C'
bond_ids = [0, 1]
mask = [0, 1, 0, 0, 0, 1, 1, 1]

# perform the scan
distances, energies = evaluate_bond(molecule, bond_ids, mask,  calculator_list, search_space=[1.0, 6.0], resolution=80, mol_name=mol_name, visualize=True)
plot_bond(distances, energies, , calculator_colors, mol_name=mol_name, calc_name=CALC_NAME, bond_name=bond_name)
# Out:
# computing C0-C1 PES
# scan range [1.0, 6.0] Å
# evaluating 80 distances
# distances:
# [1.         1.06329114 1.12658228 1.18987342 1.25316456 1.3164557
#  1.37974684 1.44303797 1.50632911 1.56962025 1.63291139 1.69620253
#  1.75949367 1.82278481 1.88607595 1.94936709 2.01265823 2.07594937
#  2.13924051 2.20253165 2.26582278 2.32911392 2.39240506 2.4556962
#  2.51898734 2.58227848 2.64556962 2.70886076 2.7721519  2.83544304
#  2.89873418 2.96202532 3.02531646 3.08860759 3.15189873 3.21518987
#  3.27848101 3.34177215 3.40506329 3.46835443 3.53164557 3.59493671
#  3.65822785 3.72151899 3.78481013 3.84810127 3.91139241 3.97468354
#  4.03797468 4.10126582 4.16455696 4.2278481  4.29113924 4.35443038
#  4.41772152 4.48101266 4.5443038  4.60759494 4.67088608 4.73417722
#  4.79746835 4.86075949 4.92405063 4.98734177 5.05063291 5.11392405
#  5.17721519 5.24050633 5.30379747 5.36708861 5.43037975 5.49367089
#  5.55696203 5.62025316 5.6835443  5.74683544 5.81012658 5.87341772
#  5.93670886 6.        ]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 12
#       9 mask = [0, 1, 0, 0, 0, 1, 1, 1]
#      11 # perform the scan
# ---> 12 distances, energies = evaluate_bond(molecule, bond_ids, mask,  calculator_list, search_space=[1.0, 6.0], resolution=80, mol_name=mol_name, visualize=True)
#      13 plot_bond(distances, energies, ['UMA_small'], calculator_colors, mol_name=mol_name, calc_name=CALC_NAME, bond_name=bond_name)
#
# Cell In[10], line 63, in evaluate_bond(molecule, bond_ids, mask, calculator_list, search_space, resolution, mol_name, visualize)
#      61 if visualize:
#      62     if len(calculator_list) == 1:
# ---> 63         traj = trajectory.TrajectoryReader(os.path.join('./', mol_name, 'bond_scan.traj'))
#      64         view(traj, viewer='ase')
#      66 return dist_list, energies
#
# File ~/miniconda3/envs/ASE_UMA_test/lib/python3.12/site-packages/ase/io/trajectory.py:243, in TrajectoryReader.__init__(self, filename)
#     240 self.pbc = None
#     241 self.masses = None
# --> 243 self._open(filename)
#
# File ~/miniconda3/envs/ASE_UMA_test/lib/python3.12/site-packages/ase/io/trajectory.py:253, in TrajectoryReader._open(self, filename)
#     251 def _open(self, filename):
#     252     import ase.io.ulm as ulm
# --> 253     self.backend = ulm.open(filename, 'r')
#     254     self._read_header()
#
# File ~/miniconda3/envs/ASE_UMA_test/lib/python3.12/site-packages/ase/io/ulm.py:157, in open(filename, mode, index, tag)
#     155 if mode == 'r':
#     156     assert tag is None
# --> 157     return Reader(filename, index or 0)
#     158 if mode not in 'wa':
#     159     2 / 0
#
# File ~/miniconda3/envs/ASE_UMA_test/lib/python3.12/site-packages/ase/io/ulm.py:480, in Reader.__init__(self, fd, index, data, _little_endian)
#     478 if not hasattr(fd, 'read'):
#     479     self.must_close_fd = True
# --> 480     fd = Path(fd).open('rb')
#     482 self._fd = fd
#     483 self._index = index
#
# File ~/miniconda3/envs/ASE_UMA_test/lib/python3.12/pathlib.py:1013, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1011 if "b" not in mode:
#    1012     encoding = io.text_encoding(encoding)
# -> 1013 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ethane/bond_scan.traj'

# %%
# define the molecule
mol_name = 'ethane'
molecule = build.molecule('C2H6')

# parameters

bond_name = 'C-C'
bond_ids = [0, 1]
mask = [0, 1, 0, 0, 0, 1, 1, 1]

# perform the scan
distances, energies = evaluate_bond(molecule, bond_ids, mask,  calculator_list, search_space=[1.0, 6.0], resolution=80, mol_name=mol_name, visualize=False)
plot_bond(distances, energies, ['UMA_small'], calculator_colors, mol_name=mol_name, calc_name='UMA', bond_name=bond_name)
# Out:
# computing C0-C1 PES
# scan range [1.0, 6.0] Å
# evaluating 80 distances
# distances:
# [1.         1.06329114 1.12658228 1.18987342 1.25316456 1.3164557
#  1.37974684 1.44303797 1.50632911 1.56962025 1.63291139 1.69620253
#  1.75949367 1.82278481 1.88607595 1.94936709 2.01265823 2.07594937
#  2.13924051 2.20253165 2.26582278 2.32911392 2.39240506 2.4556962
#  2.51898734 2.58227848 2.64556962 2.70886076 2.7721519  2.83544304
#  2.89873418 2.96202532 3.02531646 3.08860759 3.15189873 3.21518987
#  3.27848101 3.34177215 3.40506329 3.46835443 3.53164557 3.59493671
#  3.65822785 3.72151899 3.78481013 3.84810127 3.91139241 3.97468354
#  4.03797468 4.10126582 4.16455696 4.2278481  4.29113924 4.35443038
#  4.41772152 4.48101266 4.5443038  4.60759494 4.67088608 4.73417722
#  4.79746835 4.86075949 4.92405063 4.98734177 5.05063291 5.11392405
#  5.17721519 5.24050633 5.30379747 5.36708861 5.43037975 5.49367089
#  5.55696203 5.62025316 5.6835443  5.74683544 5.81012658 5.87341772
#  5.93670886 6.        ]

# %%
# define the molecule
mol_name = 'ethanol'
molecule = build.molecule('CH3CH2OH')

bond_name = 'CO'
bond_ids = [1, 2]
mask = [0, 0, 1, 1, 0, 0, 0, 0, 0]

# perform the scan
distances, energies = evaluate_bond(molecule, bond_ids, mask,  calculator_list, search_space=[1.0, 6.0], resolution=80, mol_name=mol_name, visualize=True)
plot_bond(distances, energies, calculator_names, calculator_colors, mol_name=mol_name, calc_name=CALC_NAME, bond_name=bond_name)
# Out:
# computing C1-O2 PES
# scan range [1.0, 6.0] Å
# evaluating 80 distances
# distances:
# [1.         1.06329114 1.12658228 1.18987342 1.25316456 1.3164557
#  1.37974684 1.44303797 1.50632911 1.56962025 1.63291139 1.69620253
#  1.75949367 1.82278481 1.88607595 1.94936709 2.01265823 2.07594937
#  2.13924051 2.20253165 2.26582278 2.32911392 2.39240506 2.4556962
#  2.51898734 2.58227848 2.64556962 2.70886076 2.7721519  2.83544304
#  2.89873418 2.96202532 3.02531646 3.08860759 3.15189873 3.21518987
#  3.27848101 3.34177215 3.40506329 3.46835443 3.53164557 3.59493671
#  3.65822785 3.72151899 3.78481013 3.84810127 3.91139241 3.97468354
#  4.03797468 4.10126582 4.16455696 4.2278481  4.29113924 4.35443038
#  4.41772152 4.48101266 4.5443038  4.60759494 4.67088608 4.73417722
#  4.79746835 4.86075949 4.92405063 4.98734177 5.05063291 5.11392405
#  5.17721519 5.24050633 5.30379747 5.36708861 5.43037975 5.49367089
#  5.55696203 5.62025316 5.6835443  5.74683544 5.81012658 5.87341772
#  5.93670886 6.        ]

# %%
# define the molecule
mol_name = 'ethanol'
molecule = build.molecule('CH3CH2OH')

bond_name = 'CO'
bond_ids = [1, 2]
mask = [0, 0, 1, 1, 0, 0, 0, 0, 0]

# perform the scan
distances, energies = evaluate_bond(molecule, bond_ids, mask,  calculator_list, search_space=[1.0, 6.0], resolution=80, mol_name=mol_name, visualize=False)
plot_bond(distances, energies, ['UMA_small'], calculator_colors, mol_name=mol_name, calc_name='UMA', bond_name=bond_name)
# Out:
# computing C1-O2 PES
# scan range [1.0, 6.0] Å
# evaluating 80 distances
# distances:
# [1.         1.06329114 1.12658228 1.18987342 1.25316456 1.3164557
#  1.37974684 1.44303797 1.50632911 1.56962025 1.63291139 1.69620253
#  1.75949367 1.82278481 1.88607595 1.94936709 2.01265823 2.07594937
#  2.13924051 2.20253165 2.26582278 2.32911392 2.39240506 2.4556962
#  2.51898734 2.58227848 2.64556962 2.70886076 2.7721519  2.83544304
#  2.89873418 2.96202532 3.02531646 3.08860759 3.15189873 3.21518987
#  3.27848101 3.34177215 3.40506329 3.46835443 3.53164557 3.59493671
#  3.65822785 3.72151899 3.78481013 3.84810127 3.91139241 3.97468354
#  4.03797468 4.10126582 4.16455696 4.2278481  4.29113924 4.35443038
#  4.41772152 4.48101266 4.5443038  4.60759494 4.67088608 4.73417722
#  4.79746835 4.86075949 4.92405063 4.98734177 5.05063291 5.11392405
#  5.17721519 5.24050633 5.30379747 5.36708861 5.43037975 5.49367089
#  5.55696203 5.62025316 5.6835443  5.74683544 5.81012658 5.87341772
#  5.93670886 6.        ]

# %%
# define the molecule
mol_name = 'ethanol'
molecule = build.molecule('CH3CH2OH')

bond_name = 'OH'
bond_ids = [2, 3]
mask = [0, 0, 0, 1, 0, 0, 0, 0, 0]

# perform the scan
distances, energies = evaluate_bond(molecule, bond_ids, mask,  calculator_list, search_space=[0.7, 6.0], resolution=80, mol_name=mol_name, visualize=True)
plot_bond(distances, energies, calculator_names, calculator_colors, mol_name=mol_name, calc_name=CALC_NAME, bond_name=bond_name)
# Out:
# computing O2-H3 PES
# scan range [0.7, 6.0] Å
# evaluating 80 distances
# distances:
# [0.7        0.76708861 0.83417722 0.90126582 0.96835443 1.03544304
#  1.10253165 1.16962025 1.23670886 1.30379747 1.37088608 1.43797468
#  1.50506329 1.5721519  1.63924051 1.70632911 1.77341772 1.84050633
#  1.90759494 1.97468354 2.04177215 2.10886076 2.17594937 2.24303797
#  2.31012658 2.37721519 2.4443038  2.51139241 2.57848101 2.64556962
#  2.71265823 2.77974684 2.84683544 2.91392405 2.98101266 3.04810127
#  3.11518987 3.18227848 3.24936709 3.3164557  3.3835443  3.45063291
#  3.51772152 3.58481013 3.65189873 3.71898734 3.78607595 3.85316456
#  3.92025316 3.98734177 4.05443038 4.12151899 4.18860759 4.2556962
#  4.32278481 4.38987342 4.45696203 4.52405063 4.59113924 4.65822785
#  4.72531646 4.79240506 4.85949367 4.92658228 4.99367089 5.06075949
#  5.1278481  5.19493671 5.26202532 5.32911392 5.39620253 5.46329114
#  5.53037975 5.59746835 5.66455696 5.73164557 5.79873418 5.86582278
#  5.93291139 6.        ]

# %%
# define the molecule
mol_name = 'ethanol'
molecule = build.molecule('CH3CH2OH')

bond_name = 'OH'
bond_ids = [2, 3]
mask = [0, 0, 0, 1, 0, 0, 0, 0, 0]

# perform the scan
distances, energies = evaluate_bond(molecule, bond_ids, mask,  calculator_list, search_space=[0.7, 6.0], resolution=80, mol_name=mol_name, visualize=False)
plot_bond(distances, energies, ['UMA_small'], calculator_colors, mol_name=mol_name, calc_name='UMA', bond_name=bond_name)
# Out:
# computing O2-H3 PES
# scan range [0.7, 6.0] Å
# evaluating 80 distances
# distances:
# [0.7        0.76708861 0.83417722 0.90126582 0.96835443 1.03544304
#  1.10253165 1.16962025 1.23670886 1.30379747 1.37088608 1.43797468
#  1.50506329 1.5721519  1.63924051 1.70632911 1.77341772 1.84050633
#  1.90759494 1.97468354 2.04177215 2.10886076 2.17594937 2.24303797
#  2.31012658 2.37721519 2.4443038  2.51139241 2.57848101 2.64556962
#  2.71265823 2.77974684 2.84683544 2.91392405 2.98101266 3.04810127
#  3.11518987 3.18227848 3.24936709 3.3164557  3.3835443  3.45063291
#  3.51772152 3.58481013 3.65189873 3.71898734 3.78607595 3.85316456
#  3.92025316 3.98734177 4.05443038 4.12151899 4.18860759 4.2556962
#  4.32278481 4.38987342 4.45696203 4.52405063 4.59113924 4.65822785
#  4.72531646 4.79240506 4.85949367 4.92658228 4.99367089 5.06075949
#  5.1278481  5.19493671 5.26202532 5.32911392 5.39620253 5.46329114
#  5.53037975 5.59746835 5.66455696 5.73164557 5.79873418 5.86582278
#  5.93291139 6.        ]

# %% [markdown]
# # __Cylobutadiene Analysis__
# Assess the asymmetry knowledge of the models

# %%
# define the molecule
mol_name = 'cylobutadiene'
molecule = pubchem_atoms_search(smiles='C1=CC=C1')

# select the C-C bond and provide the mask

for atom in molecule:
    print(atom.index, atom.symbol)
#view(molecule, viewer='ase')


# hortitzontal
# C: 0 2, H: 4 6, distancia curta amb C: 1 3, H: 5 7 
# [0, 1], [2, 3], [4, 5], [6, 7]
bond_ids_h = [0, 1]
mask_h = [0, 1, 0, 1, 0, 1, 0, 1]

# vertical 
# C: 0 1, H: 4 5, distancia llarga amb C: 2 3, H: 6 7  
bond_ids_v = [0, 2]
mask_v = [0, 0, 1, 1, 0, 0, 1, 1]

mol_name = 'cylobutadiene'
bond_name = 'CC'
molecule = pubchem_atoms_search(smiles='C1=CC=C1')

# set C-C distances
molecule.set_distance(bond_ids_h[0], bond_ids_h[1], 1.400000, fix=0, mask=mask_h)
molecule.set_distance(bond_ids_v[0], bond_ids_v[1], 1.400000, fix=0, mask=mask_v)

# set C-H distances
molecule.set_distance(0, 4, 1.08, fix=0)
molecule.set_distance(1, 5, 1.08, fix=0)
molecule.set_distance(2, 6, 1.08, fix=0)
molecule.set_distance(3, 7, 1.08, fix=0)

#view(molecule, viewer='ase')
# Out:
# 0 C
# 1 C
# 2 C
# 3 C
# 4 H
# 5 H
# 6 H
# 7 H

# %%
# deformació vertical
# define square
mol_name = 'cylobutadiene'
bond_name = 'CC'
molecule = pubchem_atoms_search(smiles='C1=CC=C1')
molecule.set_distance(bond_ids_h[0], bond_ids_h[1], 1.400000, fix=0, mask=mask_h)
molecule.set_distance(bond_ids_v[0], bond_ids_v[1], 1.400000, fix=0, mask=mask_v)
molecule.set_distance(0, 4, 1.08, fix=0)
molecule.set_distance(1, 5, 1.08, fix=0)
molecule.set_distance(2, 6, 1.08, fix=0)
molecule.set_distance(3, 7, 1.08, fix=0)
#view(molecule)

distances_v, energies_v = evaluate_bond(molecule, bond_ids_v, mask_v,  calculator_list, search_space=[1.2, 1.8], resolution=60, mol_name=mol_name, visualize=True)
plot_bond(distances_v, energies_v, calculator_names, calculator_colors, mol_name=mol_name, calc_name=CALC_NAME, bond_name=bond_name+' vertical')
# Out:
# computing C0-C2 PES
# scan range [1.2, 1.8] Å
# evaluating 60 distances
# distances:
# [1.2        1.21016949 1.22033898 1.23050847 1.24067797 1.25084746
#  1.26101695 1.27118644 1.28135593 1.29152542 1.30169492 1.31186441
#  1.3220339  1.33220339 1.34237288 1.35254237 1.36271186 1.37288136
#  1.38305085 1.39322034 1.40338983 1.41355932 1.42372881 1.43389831
#  1.4440678  1.45423729 1.46440678 1.47457627 1.48474576 1.49491525
#  1.50508475 1.51525424 1.52542373 1.53559322 1.54576271 1.5559322
#  1.56610169 1.57627119 1.58644068 1.59661017 1.60677966 1.61694915
#  1.62711864 1.63728814 1.64745763 1.65762712 1.66779661 1.6779661
#  1.68813559 1.69830508 1.70847458 1.71864407 1.72881356 1.73898305
#  1.74915254 1.75932203 1.76949153 1.77966102 1.78983051 1.8       ]

# %%
# deformació vertical
# define square
mol_name = 'cylobutadiene'
bond_name = 'CC'
molecule = pubchem_atoms_search(smiles='C1=CC=C1')
molecule.set_distance(bond_ids_h[0], bond_ids_h[1], 1.400000, fix=0, mask=mask_h)
molecule.set_distance(bond_ids_v[0], bond_ids_v[1], 1.400000, fix=0, mask=mask_v)
molecule.set_distance(0, 4, 1.08, fix=0)
molecule.set_distance(1, 5, 1.08, fix=0)
molecule.set_distance(2, 6, 1.08, fix=0)
molecule.set_distance(3, 7, 1.08, fix=0)
#view(molecule)

distances_v, energies_v = evaluate_bond(molecule, bond_ids_v, mask_v,  calculator_list, search_space=[1.2, 1.8], resolution=60, mol_name=mol_name, visualize=False)
plot_bond(distances_v, energies_v, ['UMA_small'], calculator_colors, mol_name=mol_name, calc_name='UMA', bond_name=bond_name+' vertical')
# Out:
# computing C0-C2 PES
# scan range [1.2, 1.8] Å
# evaluating 60 distances
# distances:
# [1.2        1.21016949 1.22033898 1.23050847 1.24067797 1.25084746
#  1.26101695 1.27118644 1.28135593 1.29152542 1.30169492 1.31186441
#  1.3220339  1.33220339 1.34237288 1.35254237 1.36271186 1.37288136
#  1.38305085 1.39322034 1.40338983 1.41355932 1.42372881 1.43389831
#  1.4440678  1.45423729 1.46440678 1.47457627 1.48474576 1.49491525
#  1.50508475 1.51525424 1.52542373 1.53559322 1.54576271 1.5559322
#  1.56610169 1.57627119 1.58644068 1.59661017 1.60677966 1.61694915
#  1.62711864 1.63728814 1.64745763 1.65762712 1.66779661 1.6779661
#  1.68813559 1.69830508 1.70847458 1.71864407 1.72881356 1.73898305
#  1.74915254 1.75932203 1.76949153 1.77966102 1.78983051 1.8       ]

# %%
# deformació horitzontal
mol_name = 'cylobutadiene'
bond_name = 'CC'
molecule = pubchem_atoms_search(smiles='C1=CC=C1')
molecule.set_distance(bond_ids_h[0], bond_ids_h[1], 1.400000, fix=0, mask=mask_h)
molecule.set_distance(bond_ids_v[0], bond_ids_v[1], 1.400000, fix=0, mask=mask_v)
molecule.set_distance(0, 4, 1.08, fix=0)
molecule.set_distance(1, 5, 1.08, fix=0)
molecule.set_distance(2, 6, 1.08, fix=0)
molecule.set_distance(3, 7, 1.08, fix=0)
#view(molecule)

# deformació hortiztonal
distances_h, energies_h = evaluate_bond(molecule, bond_ids_h, mask_h,  calculator_list, search_space=[1.2, 1.8], resolution=60, mol_name=mol_name, visualize=True)
plot_bond(distances_h, energies_h, calculator_names, calculator_colors, mol_name=mol_name, calc_name=CALC_NAME, bond_name=bond_name+' horizontal')
# Out:
# computing C0-C1 PES
# scan range [1.2, 1.8] Å
# evaluating 60 distances
# distances:
# [1.2        1.21016949 1.22033898 1.23050847 1.24067797 1.25084746
#  1.26101695 1.27118644 1.28135593 1.29152542 1.30169492 1.31186441
#  1.3220339  1.33220339 1.34237288 1.35254237 1.36271186 1.37288136
#  1.38305085 1.39322034 1.40338983 1.41355932 1.42372881 1.43389831
#  1.4440678  1.45423729 1.46440678 1.47457627 1.48474576 1.49491525
#  1.50508475 1.51525424 1.52542373 1.53559322 1.54576271 1.5559322
#  1.56610169 1.57627119 1.58644068 1.59661017 1.60677966 1.61694915
#  1.62711864 1.63728814 1.64745763 1.65762712 1.66779661 1.6779661
#  1.68813559 1.69830508 1.70847458 1.71864407 1.72881356 1.73898305
#  1.74915254 1.75932203 1.76949153 1.77966102 1.78983051 1.8       ]

# %%
# deformació horitzontal
mol_name = 'cylobutadiene'
bond_name = 'CC'
molecule = pubchem_atoms_search(smiles='C1=CC=C1')
molecule.set_distance(bond_ids_h[0], bond_ids_h[1], 1.400000, fix=0, mask=mask_h)
molecule.set_distance(bond_ids_v[0], bond_ids_v[1], 1.400000, fix=0, mask=mask_v)
molecule.set_distance(0, 4, 1.08, fix=0)
molecule.set_distance(1, 5, 1.08, fix=0)
molecule.set_distance(2, 6, 1.08, fix=0)
molecule.set_distance(3, 7, 1.08, fix=0)
#view(molecule)

# deformació hortiztonal
distances_h, energies_h = evaluate_bond(molecule, bond_ids_h, mask_h,  calculator_list, search_space=[1.2, 1.8], resolution=60, mol_name=mol_name, visualize=False)
plot_bond(distances_h, energies_h, ['UMA_small'], calculator_colors, mol_name=mol_name, calc_name='UMA', bond_name=bond_name+' horizontal')
# Out:
# computing C0-C1 PES
# scan range [1.2, 1.8] Å
# evaluating 60 distances
# distances:
# [1.2        1.21016949 1.22033898 1.23050847 1.24067797 1.25084746
#  1.26101695 1.27118644 1.28135593 1.29152542 1.30169492 1.31186441
#  1.3220339  1.33220339 1.34237288 1.35254237 1.36271186 1.37288136
#  1.38305085 1.39322034 1.40338983 1.41355932 1.42372881 1.43389831
#  1.4440678  1.45423729 1.46440678 1.47457627 1.48474576 1.49491525
#  1.50508475 1.51525424 1.52542373 1.53559322 1.54576271 1.5559322
#  1.56610169 1.57627119 1.58644068 1.59661017 1.60677966 1.61694915
#  1.62711864 1.63728814 1.64745763 1.65762712 1.66779661 1.6779661
#  1.68813559 1.69830508 1.70847458 1.71864407 1.72881356 1.73898305
#  1.74915254 1.75932203 1.76949153 1.77966102 1.78983051 1.8       ]

# %%
# get the reference DFT structure 
ref_struct_path = '/Users/sergiortizropero/TFG_phys/NNPs_TFG/scripts/gaussian/xyz_structures/cyclobutadiene_tight_DFT_wb97xd_6-31d.xyz'
ref_molecule = read(ref_struct_path)
vertical = ref_molecule.get_distance(0, 3)
horzontal = ref_molecule.get_distance(0, 1)
print(vertical, horzontal)
#view(ref_molecule)
# Out:
# 1.3310960000634815 1.571132000135253

# %% [markdown]
# **ORB-D3-V2 PES**

# %%
# calculator for this 2D PES scan
CALCULATOR = orb_calc_d3_v2
CALCULATOR_NAME = 'ORB-D3-v2'

energy_matrix = []

# initial square geometry
molecule = pubchem_atoms_search(smiles='C1=CC=C1')
molecule.set_distance(bond_ids_h[0], bond_ids_h[1], 1.400000, fix=0, mask=mask_h)
molecule.set_distance(bond_ids_v[0], bond_ids_v[1], 1.400000, fix=0, mask=mask_v)
molecule.set_distance(0, 4, 1.08, fix=0)
molecule.set_distance(1, 5, 1.08, fix=0)
molecule.set_distance(2, 6, 1.08, fix=0)
molecule.set_distance(3, 7, 1.08, fix=0)

work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryWriter(filename=traj_path, mode='w')

for d_x in distances_h:

    temp_list = []

    for d_y in distances_v:
        molecule.set_distance(bond_ids_h[0], bond_ids_h[1], d_x, fix=0, mask=mask_h)
        molecule.set_distance(bond_ids_v[0], bond_ids_v[1], d_y, fix=0, mask=mask_v)

        molecule.calc = CALCULATOR
        potential_e = molecule.get_potential_energy()
        temp_list.append(potential_e)

        traj.write(molecule)

    energy_matrix.append(temp_list)

# %%
corrected_energy_matrix = np.array(energy_matrix) - np.min(np.array(energy_matrix))

# %%
work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryReader(traj_path)
view(traj, viewer='ase')
# Out:
# <Popen: returncode: None args: ['/Users/sergiortizropero/miniconda3/envs/ASE...>

# %%
exes = [i for i in distances_h]


fig, ax = plt.subplots()
im = ax.pcolormesh(distances_h, distances_v, corrected_energy_matrix, vmax=0.3, cmap='BuPu_r', label=r'$\textnormal{}$')
ax.scatter(horzontal, vertical, color='red', marker='x', label=r'$\textnormal{DFT reference}$', s=60)
ax.scatter(vertical, horzontal, color='red', marker='x', s=60)
ax.plot(exes, exes, ls=':', color='black', label=r'$\textnormal{symmetry axis}$')
ax.set(xlabel=r'$\textnormal{horizontal distance (Å)}$', ylabel=r'$\textnormal{vertical distance (Å)}$')

ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
fig.colorbar(im, ax=ax, label=r'$\textnormal{Potential energy (eV)}\quad\textnormal{\textbf{'+f'{CALCULATOR_NAME}'+r'}}$')
fig.savefig(os.path.join(work_dir, f'{mol_name}_{CALCULATOR_NAME}'+'_2D_PES.png'), dpi=400)
fig.show()
# Out:
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_83060/2963044723.py:11: UserWarning: Legend does not support handles for QuadMesh instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_83060/2963044723.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# **ORB-v2 PES**

# %%
# calculator for this 2D PES scan
CALCULATOR = orb_calc_v2
CALCULATOR_NAME = 'ORB-v2'

energy_matrix = []

# initial square geometry
molecule = pubchem_atoms_search(smiles='C1=CC=C1')
molecule.set_distance(bond_ids_h[0], bond_ids_h[1], 1.400000, fix=0, mask=mask_h)
molecule.set_distance(bond_ids_v[0], bond_ids_v[1], 1.400000, fix=0, mask=mask_v)
molecule.set_distance(0, 4, 1.08, fix=0)
molecule.set_distance(1, 5, 1.08, fix=0)
molecule.set_distance(2, 6, 1.08, fix=0)
molecule.set_distance(3, 7, 1.08, fix=0)

work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryWriter(filename=traj_path, mode='w')

for d_x in distances_h:

    temp_list = []

    for d_y in distances_v:
        molecule.set_distance(bond_ids_h[0], bond_ids_h[1], d_x, fix=0, mask=mask_h)
        molecule.set_distance(bond_ids_v[0], bond_ids_v[1], d_y, fix=0, mask=mask_v)

        molecule.calc = CALCULATOR
        potential_e = molecule.get_potential_energy()
        temp_list.append(potential_e)

        traj.write(molecule)

    energy_matrix.append(temp_list)
# Out:
# Traceback (most recent call last):
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/gui/pipe.py", line 32, in <module>
#     main()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/gui/pipe.py", line 28, in main
#     plt.show()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/matplotlib/pyplot.py", line 614, in show
#     return _get_backend_mod().show(*args, **kwargs)
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py", line 90, in show
#     display(
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/IPython/core/display_functions.py", line 265, in display
#     print(*objs)
# ValueError: I/O operation on closed file.
# 2025-03-08 23:04:36.704 python[85046:1580519] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-08 23:04:36.704 python[85046:1580519] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
corrected_energy_matrix = np.array(energy_matrix) - np.min(np.array(energy_matrix))

# %%
work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryReader(traj_path)
view(traj, viewer='ase')
# Out:
# <Popen: returncode: None args: ['/Users/sergiortizropero/miniconda3/envs/ASE...>

# %%
exes = [i for i in distances_h]


fig, ax = plt.subplots()
im = ax.pcolormesh(distances_h, distances_v, corrected_energy_matrix, vmax=0.7, cmap='BuPu_r', label=r'$\textnormal{}$')
ax.scatter(horzontal, vertical, color='red', marker='x', label=r'$\textnormal{DFT reference}$', s=60)
ax.scatter(vertical, horzontal, color='red', marker='x', s=60)
ax.plot(exes, exes, ls=':', color='black', label=r'$\textnormal{symmetry axis}$')
ax.set(xlabel=r'$\textnormal{horizontal distance (Å)}$', ylabel=r'$\textnormal{vertical distance (Å)}$')

ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
fig.colorbar(im, ax=ax, label=r'$\textnormal{Potential energy (eV)}\quad\textnormal{\textbf{'+f'{CALCULATOR_NAME}'+r'}}$')
fig.savefig(os.path.join(work_dir, f'{mol_name}_{CALCULATOR_NAME}'+'_2D_PES.png'), dpi=400)
fig.show()
# Out:
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_83060/3739279841.py:11: UserWarning: Legend does not support handles for QuadMesh instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_83060/3739279841.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# **MACE-OFF PES**

# %%
# calculator for this 2D PES scan
CALCULATOR = maceoff
CALCULATOR_NAME = 'MACE-OFF'

energy_matrix = []

# initial square geometry
molecule = pubchem_atoms_search(smiles='C1=CC=C1')
molecule.set_distance(bond_ids_h[0], bond_ids_h[1], 1.400000, fix=0, mask=mask_h)
molecule.set_distance(bond_ids_v[0], bond_ids_v[1], 1.400000, fix=0, mask=mask_v)
molecule.set_distance(0, 4, 1.08, fix=0)
molecule.set_distance(1, 5, 1.08, fix=0)
molecule.set_distance(2, 6, 1.08, fix=0)
molecule.set_distance(3, 7, 1.08, fix=0)

work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryWriter(filename=traj_path, mode='w')

for d_x in distances_h:

    temp_list = []

    for d_y in distances_v:
        molecule.set_distance(bond_ids_h[0], bond_ids_h[1], d_x, fix=0, mask=mask_h)
        molecule.set_distance(bond_ids_v[0], bond_ids_v[1], d_y, fix=0, mask=mask_v)

        molecule.calc = CALCULATOR
        potential_e = molecule.get_potential_energy()
        temp_list.append(potential_e)

        traj.write(molecule)

    energy_matrix.append(temp_list)
# Out:
# Traceback (most recent call last):
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/gui/pipe.py", line 32, in <module>
#     main()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/gui/pipe.py", line 28, in main
#     plt.show()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/matplotlib/pyplot.py", line 614, in show
#     return _get_backend_mod().show(*args, **kwargs)
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py", line 90, in show
#     display(
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/IPython/core/display_functions.py", line 265, in display
#     print(*objs)
# ValueError: I/O operation on closed file.
# 2025-03-08 23:06:54.404 python[85121:1581991] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-08 23:06:54.404 python[85121:1581991] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
corrected_energy_matrix = np.array(energy_matrix) - np.min(np.array(energy_matrix))

# %%
work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryReader(traj_path)
view(traj, viewer='ase')
# Out:
# <Popen: returncode: None args: ['/Users/sergiortizropero/miniconda3/envs/ASE...>

# %%
exes = [i for i in distances_h]


fig, ax = plt.subplots()
im = ax.pcolormesh(distances_h, distances_v, corrected_energy_matrix, vmax=0.5, cmap='BuPu_r', label=r'$\textnormal{}$')
ax.scatter(horzontal, vertical, color='red', marker='x', label=r'$\textnormal{DFT reference}$', s=60)
ax.scatter(vertical, horzontal, color='red', marker='x', s=60)
ax.plot(exes, exes, ls=':', color='black', label=r'$\textnormal{symmetry axis}$')
ax.set(xlabel=r'$\textnormal{horizontal distance (Å)}$', ylabel=r'$\textnormal{vertical distance (Å)}$')

ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
fig.colorbar(im, ax=ax, label=r'$\textnormal{Potential energy (eV)}\quad\textnormal{\textbf{'+f'{CALCULATOR_NAME}'+r'}}$')
fig.savefig(os.path.join(work_dir, f'{mol_name}_{CALCULATOR_NAME}'+'_2D_PES.png'), dpi=400)
fig.show()
# Out:
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_83060/2440039475.py:11: UserWarning: Legend does not support handles for QuadMesh instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_83060/2440039475.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# **MACE-MP PES**

# %%
# calculator for this 2D PES scan
CALCULATOR = macemp
CALCULATOR_NAME = 'MACE-MP'

energy_matrix = []

# initial square geometry
molecule = pubchem_atoms_search(smiles='C1=CC=C1')
molecule.set_distance(bond_ids_h[0], bond_ids_h[1], 1.400000, fix=0, mask=mask_h)
molecule.set_distance(bond_ids_v[0], bond_ids_v[1], 1.400000, fix=0, mask=mask_v)
molecule.set_distance(0, 4, 1.08, fix=0)
molecule.set_distance(1, 5, 1.08, fix=0)
molecule.set_distance(2, 6, 1.08, fix=0)
molecule.set_distance(3, 7, 1.08, fix=0)

work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryWriter(filename=traj_path, mode='w')

for d_x in distances_h:

    temp_list = []

    for d_y in distances_v:
        molecule.set_distance(bond_ids_h[0], bond_ids_h[1], d_x, fix=0, mask=mask_h)
        molecule.set_distance(bond_ids_v[0], bond_ids_v[1], d_y, fix=0, mask=mask_v)

        molecule.calc = CALCULATOR
        potential_e = molecule.get_potential_energy()
        temp_list.append(potential_e)

        traj.write(molecule)

    energy_matrix.append(temp_list)
# Out:
# Traceback (most recent call last):
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/gui/pipe.py", line 32, in <module>
#     main()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/gui/pipe.py", line 28, in main
#     plt.show()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/matplotlib/pyplot.py", line 614, in show
#     return _get_backend_mod().show(*args, **kwargs)
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py", line 90, in show
#     display(
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/IPython/core/display_functions.py", line 265, in display
#     print(*objs)
# ValueError: I/O operation on closed file.
# 2025-03-08 23:10:16.927 python[85190:1583567] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-08 23:10:16.927 python[85190:1583567] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
corrected_energy_matrix = np.array(energy_matrix) - np.min(np.array(energy_matrix))

# %%
work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryReader(traj_path)
view(traj, viewer='ase')
# Out:
# <Popen: returncode: None args: ['/Users/sergiortizropero/miniconda3/envs/ASE...>

# %%
exes = [i for i in distances_h]


fig, ax = plt.subplots()
im = ax.pcolormesh(distances_h, distances_v, corrected_energy_matrix, vmax=0.7, cmap='BuPu_r', label=r'$\textnormal{}$')
ax.scatter(horzontal, vertical, color='red', marker='x', label=r'$\textnormal{DFT reference}$', s=60)
ax.scatter(vertical, horzontal, color='red', marker='x', s=60)
ax.plot(exes, exes, ls=':', color='black', label=r'$\textnormal{symmetry axis}$')
ax.set(xlabel=r'$\textnormal{horizontal distance (Å)}$', ylabel=r'$\textnormal{vertical distance (Å)}$')

ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
fig.colorbar(im, ax=ax, label=r'$\textnormal{Potential energy (eV)}\quad\textnormal{\textbf{'+f'{CALCULATOR_NAME}'+r'}}$')
fig.savefig(os.path.join(work_dir, f'{mol_name}_{CALCULATOR_NAME}'+'_2D_PES.png'), dpi=400)
fig.show()
# Out:
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_83060/3739279841.py:11: UserWarning: Legend does not support handles for QuadMesh instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_83060/3739279841.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# **ANI-1x PES**

# %%
# calculator for this 2D PES scan
CALCULATOR = ani1x_calc
CALCULATOR_NAME = 'ANI-1x'

energy_matrix = []

# initial square geometry
molecule = pubchem_atoms_search(smiles='C1=CC=C1')
molecule.set_distance(bond_ids_h[0], bond_ids_h[1], 1.400000, fix=0, mask=mask_h)
molecule.set_distance(bond_ids_v[0], bond_ids_v[1], 1.400000, fix=0, mask=mask_v)
molecule.set_distance(0, 4, 1.08, fix=0)
molecule.set_distance(1, 5, 1.08, fix=0)
molecule.set_distance(2, 6, 1.08, fix=0)
molecule.set_distance(3, 7, 1.08, fix=0)

work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryWriter(filename=traj_path, mode='w')

for d_x in distances_h:

    temp_list = []

    for d_y in distances_v:
        molecule.set_distance(bond_ids_h[0], bond_ids_h[1], d_x, fix=0, mask=mask_h)
        molecule.set_distance(bond_ids_v[0], bond_ids_v[1], d_y, fix=0, mask=mask_v)

        molecule.calc = CALCULATOR
        potential_e = molecule.get_potential_energy()
        temp_list.append(potential_e)

        traj.write(molecule)

    energy_matrix.append(temp_list)
# Out:
# Traceback (most recent call last):
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/gui/pipe.py", line 32, in <module>
#     main()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/gui/pipe.py", line 28, in main
#     plt.show()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/matplotlib/pyplot.py", line 614, in show
#     return _get_backend_mod().show(*args, **kwargs)
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py", line 90, in show
#     display(
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/IPython/core/display_functions.py", line 265, in display
#     print(*objs)
# ValueError: I/O operation on closed file.
# 2025-03-08 23:14:32.042 python[85281:1587121] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-08 23:14:32.042 python[85281:1587121] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
corrected_energy_matrix = np.array(energy_matrix) - np.min(np.array(energy_matrix))

# %%
work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryReader(traj_path)
view(traj, viewer='ase')
# Out:
# <Popen: returncode: None args: ['/Users/sergiortizropero/miniconda3/envs/ASE...>

# %%
exes = [i for i in distances_h]


fig, ax = plt.subplots()
im = ax.pcolormesh(distances_h, distances_v, corrected_energy_matrix, vmax=0.7, cmap='BuPu_r', label=r'$\textnormal{}$')
ax.scatter(horzontal, vertical, color='red', marker='x', label=r'$\textnormal{DFT reference}$', s=60)
ax.scatter(vertical, horzontal, color='red', marker='x', s=60)
ax.plot(exes, exes, ls=':', color='black', label=r'$\textnormal{symmetry axis}$')
ax.set(xlabel=r'$\textnormal{horizontal distance (Å)}$', ylabel=r'$\textnormal{vertical distance (Å)}$')

ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
fig.colorbar(im, ax=ax, label=r'$\textnormal{Potential energy (eV)}\quad\textnormal{\textbf{'+f'{CALCULATOR_NAME}'+r'}}$')
fig.savefig(os.path.join(work_dir, f'{mol_name}_{CALCULATOR_NAME}'+'_2D_PES.png'), dpi=400)
fig.show()
# Out:
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_83060/3739279841.py:11: UserWarning: Legend does not support handles for QuadMesh instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_83060/3739279841.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# **ANI-2x PES**

# %%
# calculator for this 2D PES scan
CALCULATOR = ani2x_calc
CALCULATOR_NAME = 'ANI-2x'

energy_matrix = []

# initial square geometry
molecule = pubchem_atoms_search(smiles='C1=CC=C1')
molecule.set_distance(bond_ids_h[0], bond_ids_h[1], 1.400000, fix=0, mask=mask_h)
molecule.set_distance(bond_ids_v[0], bond_ids_v[1], 1.400000, fix=0, mask=mask_v)
molecule.set_distance(0, 4, 1.08, fix=0)
molecule.set_distance(1, 5, 1.08, fix=0)
molecule.set_distance(2, 6, 1.08, fix=0)
molecule.set_distance(3, 7, 1.08, fix=0)

work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryWriter(filename=traj_path, mode='w')

for d_x in distances_h:

    temp_list = []

    for d_y in distances_v:
        molecule.set_distance(bond_ids_h[0], bond_ids_h[1], d_x, fix=0, mask=mask_h)
        molecule.set_distance(bond_ids_v[0], bond_ids_v[1], d_y, fix=0, mask=mask_v)

        molecule.calc = CALCULATOR
        potential_e = molecule.get_potential_energy()
        temp_list.append(potential_e)

        traj.write(molecule)

    energy_matrix.append(temp_list)
# Out:
# Traceback (most recent call last):
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/gui/pipe.py", line 32, in <module>
#     main()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/gui/pipe.py", line 28, in main
#     plt.show()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/matplotlib/pyplot.py", line 614, in show
#     return _get_backend_mod().show(*args, **kwargs)
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py", line 90, in show
#     display(
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/IPython/core/display_functions.py", line 265, in display
#     print(*objs)
# ValueError: I/O operation on closed file.
# 2025-03-08 23:14:48.340 python[85310:1587608] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-08 23:14:48.340 python[85310:1587608] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
corrected_energy_matrix = np.array(energy_matrix) - np.min(np.array(energy_matrix))

# %%
work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryReader(traj_path)
view(traj, viewer='ase')
# Out:
# <Popen: returncode: None args: ['/Users/sergiortizropero/miniconda3/envs/ASE...>

# %%
exes = [i for i in distances_h]


fig, ax = plt.subplots()
im = ax.pcolormesh(distances_h, distances_v, corrected_energy_matrix, vmax=0.7, cmap='BuPu_r', label=r'$\textnormal{}$')
ax.scatter(horzontal, vertical, color='red', marker='x', label=r'$\textnormal{DFT reference}$', s=60)
ax.scatter(vertical, horzontal, color='red', marker='x', s=60)
ax.plot(exes, exes, ls=':', color='black', label=r'$\textnormal{symmetry axis}$')
ax.set(xlabel=r'$\textnormal{horizontal distance (Å)}$', ylabel=r'$\textnormal{vertical distance (Å)}$')

ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
fig.colorbar(im, ax=ax, label=r'$\textnormal{Potential energy (eV)}\quad\textnormal{\textbf{'+f'{CALCULATOR_NAME}'+r'}}$')
fig.savefig(os.path.join(work_dir, f'{mol_name}_{CALCULATOR_NAME}'+'_2D_PES.png'), dpi=400)
fig.show()
# Out:
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_83060/3739279841.py:11: UserWarning: Legend does not support handles for QuadMesh instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_83060/3739279841.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Traceback (most recent call last):
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/gui/pipe.py", line 32, in <module>
#     main()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/ase/gui/pipe.py", line 28, in main
#     plt.show()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/matplotlib/pyplot.py", line 614, in show
#     return _get_backend_mod().show(*args, **kwargs)
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py", line 90, in show
#     display(
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_all/lib/python3.10/site-packages/IPython/core/display_functions.py", line 265, in display
#     print(*objs)
# ValueError: I/O operation on closed file.
# 2025-03-08 23:15:12.339 python[85318:1588157] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-08 23:15:12.339 python[85318:1588157] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %% [markdown]
# **UMA_small PES**

# %%
# calculator for this 2D PES scan
CALCULATOR = uma_calc
CALCULATOR_NAME = 'UMA_small'

energy_matrix = []

# initial square geometry
molecule = pubchem_atoms_search(smiles='C1=CC=C1')
molecule.set_distance(bond_ids_h[0], bond_ids_h[1], 1.400000, fix=0, mask=mask_h)
molecule.set_distance(bond_ids_v[0], bond_ids_v[1], 1.400000, fix=0, mask=mask_v)
molecule.set_distance(0, 4, 1.08, fix=0)
molecule.set_distance(1, 5, 1.08, fix=0)
molecule.set_distance(2, 6, 1.08, fix=0)
molecule.set_distance(3, 7, 1.08, fix=0)
molecule.info = {"charge": 0, "spin": 1}

work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryWriter(filename=traj_path, mode='w')

for d_x in distances_h:

    temp_list = []

    for d_y in distances_v:
        molecule.set_distance(bond_ids_h[0], bond_ids_h[1], d_x, fix=0, mask=mask_h)
        molecule.set_distance(bond_ids_v[0], bond_ids_v[1], d_y, fix=0, mask=mask_v)

        molecule.calc = CALCULATOR
        potential_e = molecule.get_potential_energy()
        temp_list.append(potential_e)

        traj.write(molecule)

    energy_matrix.append(temp_list)

# %%
corrected_energy_matrix = np.array(energy_matrix) - np.min(np.array(energy_matrix))

# %%
work_dir = os.path.join(os.curdir, 'PES_distances', mol_name)
traj_path = os.path.join(work_dir, 'bond_scan_2D.traj')
traj = trajectory.TrajectoryReader(traj_path)
view(traj, viewer='ase')
# Out:
# <Popen: returncode: None args: ['/Users/sergiortizropero/miniconda3/envs/ASE...>

# %%
exes = [i for i in distances_h]


fig, ax = plt.subplots()
im = ax.pcolormesh(distances_h, distances_v, corrected_energy_matrix, vmax=0.7, cmap='BuPu_r', label=r'$\textnormal{}$')
ax.scatter(horzontal, vertical, color='red', marker='x', label=r'$\textnormal{DFT reference}$', s=60)
ax.scatter(vertical, horzontal, color='red', marker='x', s=60)
ax.plot(exes, exes, ls=':', color='black', label=r'$\textnormal{symmetry axis}$')
ax.set(xlabel=r'$\textnormal{horizontal distance (Å)}$', ylabel=r'$\textnormal{vertical distance (Å)}$')

ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
fig.colorbar(im, ax=ax, label=r'$\textnormal{Potential energy (eV)}\quad\textnormal{\textbf{'+f'{CALCULATOR_NAME}'+r'}}$')
fig.savefig(os.path.join(work_dir, f'{mol_name}_{CALCULATOR_NAME}'+'_2D_PES.png'), dpi=400)
fig.show()
# Out:
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_46764/3739279841.py:11: UserWarning: Legend does not support handles for QuadMesh instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend(loc='best', title=f'{mol_name}', title_fontsize='large')
# /var/folders/cq/s30xmbh57xndgmhg1zhwclsh0000gn/T/ipykernel_46764/3739279841.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_UMA_test/lib/python3.12/site-packages/ase/gui/pipe.py", line 34, in <module>
#     main()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_UMA_test/lib/python3.12/site-packages/ase/gui/pipe.py", line 30, in main
#     plt.show()
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_UMA_test/lib/python3.12/site-packages/matplotlib/pyplot.py", line 614, in show
#     return _get_backend_mod().show(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_UMA_test/lib/python3.12/site-packages/matplotlib_inline/backend_inline.py", line 90, in show
#     display(
#   File "/Users/sergiortizropero/miniconda3/envs/ASE_UMA_test/lib/python3.12/site-packages/IPython/core/display_functions.py", line 245, in display
#     print(*objs)
# ValueError: I/O operation on closed file.
